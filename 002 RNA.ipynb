# %%
#Rosalind transcribing DNA into RNA.
#In RNA, Thymine is replaced with Uracil.
#DNA: ATGC
#RNA: AUGC
#string.replace(old, new, count)

# %%
DNAstrand ='GATGGAACTTGACTACGTAAATT'
RNAstrand=DNAstrand.replace('T','U')
print(RNAstrand)
# Out:
# GAUGGAACUUGACUACGUAAAUU

# %%
DNAstrandrosalind ='...'
RNAstrandrosalind=DNAstrandrosalind.replace('T','U')
print(RNAstrandrosalind)
# Out:
# ...
