# %%
#Complementing a strand of DNA
#A and T are complements of each other.
#T and A are complements of each other.
#G and C are complements of each other.
#C and G are complements of each other.

#iterate over string.
#case-by-case basis replace each nt, creating the complement.
#reverse the complement to get reversecomplement.

# %%
DNAstring='...'

# %%
complement=[]
for x in range(len(DNAstring)):
    if DNAstring[x] == "A":
        complement.append("T")
    if DNAstring[x] == "T":
        complement.append("A")
    if DNAstring[x] == "G":
        complement.append("C")
    if DNAstring[x] == "C":
        complement.append("G")

stringcomplement = "".join(complement)

print(stringcomplement)
# Out:
# ...

# %%
reversecomplement=stringcomplement[::-1]
print(reversecomplement)
# Out:
# ...
