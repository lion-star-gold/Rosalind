# %%
inputs = ">Rosalind_9424 ... >Rosalind_0863 ... >Rosalind_8148 ... >Rosalind_5344 ... >Rosalind_4937 ... >Rosalind_7212 ... >Rosalind_8433 ... >Rosalind_1515 ... >Rosalind_6064 ..."
list1 = inputs.split(">")
del list1[0]
#print(list1[0])
list2 = []
for x in range(len(list1)):
    temp = list1[x].split()
    list2.append(temp)
#print("list2 looks like this:", list2)
#print("\nlist of lists created. use [0][0] notation to access sublists.")

# %%
largestGC=0
largestGCID=""
print("largest GC % so far:",largestGC)
for x in range(len(list2)):
    temp=list(list2[x][-1])
    #print(temp)
    GCcount=0
    for y in range(len(temp)):
        if temp[y] =="G" or temp[y]=="C":
            GCcount += 1
    GCpercent=(GCcount/len(temp))*100
    print("% GC:",GCpercent)
    if GCpercent > largestGC:
        largestGC=GCpercent
        largestGCID=list2[x][0]
    print("largest GC % so far:",largestGC,"name:",largestGCID)
    print(list2[x][-1])
# Out:
# largest GC % so far: 0
# % GC: 50.480769230769226
# largest GC % so far: 50.480769230769226 name: Rosalind_9424
# ...
# % GC: 50.577124868835256
# largest GC % so far: 50.577124868835256 name: Rosalind_0863
# ...
# % GC: 52.934537246049665
# largest GC % so far: 52.934537246049665 name: Rosalind_8148
# ...
# % GC: 50.70729053318824
# largest GC % so far: 52.934537246049665 name: Rosalind_8148
# ...
# % GC: 48.84526558891455
# largest GC % so far: 52.934537246049665 name: Rosalind_8148
# ...
# % GC: 48.6318407960199
# largest GC % so far: 52.934537246049665 name: Rosalind_8148
# ...
# % GC: 50.10683760683761
# largest GC % so far: 52.934537246049665 name: Rosalind_8148
# ...
# % GC: 50.05780346820809
# largest GC % so far: 52.934537246049665 name: Rosalind_8148
# ...
# % GC: 49.75845410628019
# largest GC % so far: 52.934537246049665 name: Rosalind_8148
# ...
